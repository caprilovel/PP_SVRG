# %%
import torch
import torch.nn as nn
a = nn.Sequential(
    nn.Linear(2, 2),
    nn.ReLU(),
    nn.Linear(2, 2),
)
# b is copy of a 
import copy
b =  copy.deepcopy(a)
opt_a = torch.optim.Adam(a.parameters(), lr=0.01)
opt_b = torch.optim.Adam(b.parameters(), lr=0.01)
inputx = torch.randn(2)
target = torch.randn(2)
loss_fn = nn.MSELoss()
target - a(inputx)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 8
#       2 import torch.nn as nn
#       3 a = nn.Sequential(
#       4     nn.Linear(10, 10),
#       5     nn.ReLU(),
#       6     nn.Linear(10, 10),
#       7 )
# ----> 8 b = a.deepcopy()
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1729, in Module.__getattr__(self, name)
#    1727     if name in modules:
#    1728         return modules[name]
# -> 1729 raise AttributeError(f"'{type(self).__name__}' object has no attribute '{name}'")
#
# AttributeError: 'Sequential' object has no attribute 'deepcopy'

# %%
temper_50 = [
[0.34493135868321834,0.9062906504064384]
]
SVRG_temper_80 = [
    [0.3450638310226604,0.9061947154470887],
    []
]
SGD_temper_80 = [
    
]

# %%
import numpy as np
temper_sgd_20 = [
    [0.08672469078135174,0.97798463356974,],
    [0.08575382803339685,0.9782531136481578],
    [0.08480335413893647,0.9785151243270956]
]
temper_svrg_20 = [
    [0.08104092832657037,0.9816177692819149,],
    [0.08015095451269229,0.9818447104018913,],
    [0.07928003332157385,0.9820661163725999]
]
mean_loss_sgd_20 = np.array(temper_sgd_20)[:, 0].mean()
print(mean_loss_sgd_20)
std_loss_sgd_20 = np.array(temper_sgd_20)[:, 0].std()
print(std_loss_sgd_20)
mean_acc_sgd_20 = np.array(temper_sgd_20)[:, 1].mean()
print(mean_acc_sgd_20)
std_acc_sgd_20 = np.array(temper_sgd_20)[:, 1].std()
print(std_acc_sgd_20)

mean_loss_svrg_20 = np.array(temper_svrg_20)[:, 0].mean()
print(mean_loss_svrg_20)
std_loss_svrg_20 = np.array(temper_svrg_20)[:, 0].std()
print(std_loss_svrg_20)
mean_acc_svrg_20 = np.array(temper_svrg_20)[:, 1].mean()
print(mean_acc_svrg_20)
std_acc_svrg_20 = np.array(temper_svrg_20)[:, 1].std()
print(std_acc_svrg_20)
# Out:
# 0.08576062431789501
# 0.0007843971211421463
# 0.9782509571816645
# 0.00021657731286348452
# 0.0801573053869455
# 0.0007188964018355981
# 0.9818428653521355
# 0.00018304158286733946

# %%
temper_sgd_50 = [
    [0.08777852295075486,0.9777094414893617,],
    [0.0867853297612414,0.97798463356974,],
    [0.0858130242056909,0.9782531136481578]
]
temper_svrg_50 = [
    [0.0793777304281901,0.9821600731382979],
    [0.07850429464926861,0.9823803191489362,],
    [0.07764965524367515,0.9825951933056565]
]
mean_loss_sgd_50 = np.array(temper_sgd_50)[:, 0].mean()
print(mean_loss_sgd_50)
std_loss_sgd_50 = np.array(temper_sgd_50)[:, 0
].std()
print(std_loss_sgd_50)
mean_acc_sgd_50 = np.array(temper_sgd_50)[:, 1].mean()
print(mean_acc_sgd_50)
std_acc_sgd_50 = np.array(temper_sgd_50)[:, 1].std()
print(std_acc_sgd_50)

mean_loss_svrg_50 = np.array(temper_svrg_50)[:, 0].mean()
print(mean_loss_svrg_50)
std_loss_svrg_50 = np.array(temper_svrg_50)[:, 0].std()
print(std_loss_svrg_50)
mean_acc_svrg_50 = np.array(temper_svrg_50)[:, 1].mean()
print(mean_acc_svrg_50)
std_acc_svrg_50 = np.array(temper_svrg_50)[:, 1].std()
print(std_acc_svrg_50)
# Out:
# 0.08679229230589573
# 0.000802426605982567
# 0.9779823962357531
# 0.0002219588675258544
# 0.07851056010704462
# 0.0007054976507425831
# 0.9823785285309636
# 0.00017764157686210596

# %%
temper_sgd_80 = [
    [0.0879678369497537,0.9774455618351063,],
    [0.08697158918870485,0.9777240116889939,],
    [0.08599832319951317,0.9779956700830306]
]
temper_svrg_80 = [
    [0.0807221882299734,0.9819398271276596,],
    [0.07983079375065866,0.9821627922248489,],
    [0.07895884320628503,0.9823803191489362],
]

mean_acc_sgd_80 = np.array(temper_sgd_80)[:, 1].mean()
print(mean_acc_sgd_80)
std_acc_sgd_80 = np.array(temper_sgd_80)[:, 1].std()
print(std_acc_sgd_80)
mean_loss_sgd_80 = np.array(temper_sgd_80)[:, 0].mean()
print(mean_loss_sgd_80)
std_loss_sgd_80 = np.array(temper_sgd_80)[:, 0].std()
print(std_loss_sgd_80)  


mean_acc_svrg_80 = np.array(temper_svrg_80)[:, 1].mean()
print(mean_acc_svrg_80)
std_acc_svrg_80 = np.array(temper_svrg_80)[:, 1].std()
print(std_acc_svrg_80)
mean_loss_svrg_80 = np.array(temper_svrg_80)[:, 0].mean()
print(mean_loss_svrg_80)
std_loss_svrg_80 = np.array(temper_svrg_80)[:, 0].std()
print(std_loss_svrg_80)
# Out:
# 0.9777217478690435
# 0.00022458645665480689
# 0.0869792497793239
# 0.0008040688679390185
# 0.9821609795004815
# 0.00017983468274929896
# 0.0798372750623057
# 0.0007198971795528092
